# %%
# !pip install pandas numpy psycopg2-binary sqlalchemy
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 7.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.0 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/11.0 MB 6.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/11.0 MB 7.2 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.8 MB 7.7 MB/s eta 0:00:02
# ...
